# %%
# !pip install pandas
import pandas as pd

# %%
marks = [78, 85, 90, 66, 72]
series = pd.Series(marks)
series
# Out:
# 0    78
# 1    85
# 2    90
# 3    66
# 4    72
# dtype: int64

# %%
add_5 = series + 5
print("After adding 5:", add_5)
# Out:
# After adding 5: 0    83
# 1    90
# 2    95
# 3    71
# 4    77
# dtype: int64

# %%
sub_2 = series - 2
print("After subtracting 2:", sub_2)
# Out:
# After subtracting 2: 0    76
# 1    83
# 2    88
# 3    64
# 4    70
# dtype: int64

# %%
mul_105 = series * 1.05
print("After multiplying by 1.05:", mul_105)
# Out:
# After multiplying by 1.05: 0    81.90
# 1    89.25
# 2    94.50
# 3    69.30
# 4    75.60
# dtype: float64

# %%
div_2 = series / 2
print("After dividing by 2:", div_2)
# Out:
# After dividing by 2: 0    39.0
# 1    42.5
# 2    45.0
# 3    33.0
# 4    36.0
# dtype: float64
